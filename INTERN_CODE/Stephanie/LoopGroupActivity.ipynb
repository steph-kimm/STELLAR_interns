# %%
import lightkurve as lk

# %%
from lightkurve import search_lightcurvefile
lcf = search_lightcurvefile('TIC 176872276').download_all()

# %%
for i in lcf:
    P_flux = i.PDCSAP_FLUX
    print(P_flux.targetid)
    P_flux.plot();
# Out:
# 176872276
# 176872276
# 176872276
# 176872276
# 176872276
# 176872276
# 176872276
# 176872276
# 176872276
# 176872276
# 176872276
# 176872276

# %%
type(lcf)
# Out:
# lightkurve.collections.LightCurveFileCollection
